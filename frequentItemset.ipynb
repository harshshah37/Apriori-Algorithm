# %% [markdown]
# # Fk-1 x F1 method

# %%
import pandas as pd
import itertools

#Generating Frequent 1 itemset
def generate_frequent_1_itemsets(transactions, min_support):
    item_counts = {}
    num_transactions = len(transactions)

    for transaction in transactions:
        for item in transaction:
            if item in item_counts:
                item_counts[item] += 1
            else:
                item_counts[item] = 1

    frequent_1_itemsets = {frozenset([item]) for item, count in item_counts.items() if count / num_transactions >= min_support}

    return frequent_1_itemsets

#Generating candidate itemsets i.e. Fk-1 by combining F1 itemsets and so on until we reach the last frequent itemset
#Also included pruning in this step, so that we remove candidate itemsets whose subsets are infrequent before generating new itemsets
def generate_candidates(prev_itemsets, k):
    candidates = set()

    for itemset1 in prev_itemsets:
        for itemset2 in prev_itemsets:
            if len(itemset1.union(itemset2)) == k:
                candidate = itemset1.union(itemset2)
                all_subsets_frequent = all(frozenset(subset) in prev_itemsets for subset in itertools.combinations(candidate, k-1))
                if all_subsets_frequent:
                    candidates.add(candidate)
    return candidates

#Support Counting
def count_support(transactions, candidate_itemsets):
    item_counts = {}

    for transaction in transactions:
        for itemset in candidate_itemsets:
            if itemset.issubset(transaction):
                if itemset in item_counts:
                    item_counts[itemset] += 1
                else:
                    item_counts[itemset] = 1

    return item_counts

#Association rule generation
def generate_association_rules(frequent_itemsets, transactions, min_confidence):
    association_rules = []

    for itemset in frequent_itemsets:
        if len(itemset) > 1:
            for item in itemset:
                a = frozenset([item])
                c = itemset - a
                confidence = count_support(transactions, {itemset})[itemset] / count_support(transactions, {a})[a]
                
                if confidence >= min_confidence:
                    association_rules.append((a, c, confidence))

    return association_rules

#Apriori logic
def apriori(transactions, min_support):
    k = 1
    frequent_itemsets = generate_frequent_1_itemsets(transactions, min_support)
    result = list(frequent_itemsets)
    total_itemsets = len(frequent_itemsets)
    total_candidates = len(set().union(*transactions))

    while frequent_itemsets:
        k += 1
        candidates = generate_candidates(frequent_itemsets, k)
        total_candidates += len(candidates)
        item_counts = count_support(transactions, candidates)
        frequent_itemsets = {itemset for itemset, count in item_counts.items() if count / len(transactions) >= min_support}
        if frequent_itemsets:
            total_itemsets += len(frequent_itemsets)
            result.extend(frequent_itemsets)

    return result, total_itemsets, total_candidates

# Test set used for self-testing
# transactions = [
#     {'Bread', 'Milk'},
#     {'Bread', 'Diaper', 'Beer', 'Eggs'},
#     {'Milk', 'Diaper', 'Beer', 'Coke'},
#     {'Bread', 'Milk', 'Diaper', 'Beer'},
#     {'Bread', 'Milk', 'Diaper', 'Coke'}
# ]

df = pd.read_csv('/kaggle/input/groceries/groceries.csv', usecols=lambda column: column != 'Item(s)')

transactions = df.apply(lambda row: set(row.dropna()), axis=1).tolist()

min_support = 0.01
result, total_itemsets, total_candidates = apriori(transactions, min_support)

print(f"\nTotal number of frequent itemsets: {total_itemsets}")
print(f"Total number of candidates generated: {total_candidates} \n")

print("Frequent itemsets:")
for itemset in result:
    itemset = set(itemset)
    print(itemset)

min_confidence = 0.1
association_rules = generate_association_rules(result, transactions, min_confidence)

print("\nAssociation Rules:")
for rule in association_rules:
    print(f"{set(rule[0])} => {set(rule[1])} (Confidence: {rule[2]})")
# Out:
# Total number of frequent itemsets: 333
# Total number of candidates generated: 4579
#
# Frequent itemsets:
# {'beef'}
# {'curd'}
# {'roll products'}
# {'specialty chocolate'}
# {'meat'}
# {'mustard'}
# {'ham'}
# {'shopping bags'}
# {'pickled vegetables'}
# {'seasonal products'}
# {'frankfurter'}
# {'cake bar'}
# {'baking powder'}
# {'rolls/buns'}
# {'misc. beverages'}
# {'packaged fruit/vegetables'}
# {'whipped/sour cream'}
# {'pip fruit'}
# {'white bread'}
# {'frozen dessert'}
# {'grapes'}
# {'coffee'}
# {'soda'}
# {'flower (seeds)'}
# {'processed cheese'}
# {'butter'}
# {'hygiene articles'}
# {'pasta'}
# {'salty snack'}
# {'butter milk'}
# {'frozen vegetables'}
# {'red/blush wine'}
# {'chewing gum'}
# {'detergent'}
# {'cat food'}
# {'white wine'}
# {'long life bakery product'}
# {'pastry'}
# {'other vegetables'}
# {'UHT-milk'}
# {'cling film/bags'}
# {'waffles'}
# {'liquor'}
# {'sliced cheese'}
# {'napkins'}
# {'sausage'}
# {'domestic eggs'}
# {'margarine'}
# {'ice cream'}
# {'bottled beer'}
# {'frozen meals'}
# {'hard cheese'}
# {'potted plants'}
# {'dessert'}
# {'canned vegetables'}
# {'brown bread'}
# {'whole milk'}
# {'dishes'}
# {'condensed milk'}
# {'tropical fruit'}
# {'spread cheese'}
# {'chocolate'}
# {'cream cheese'}
# {'herbs'}
# {'specialty bar'}
# {'onions'}
# {'berries'}
# {'canned fish'}
# {'soft cheese'}
# {'fruit/vegetable juice'}
# {'pork'}
# {'chicken'}
# {'semi-finished bread'}
# {'canned beer'}
# {'salt'}
# {'oil'}
# {'newspapers'}
# {'candy'}
# {'hamburger meat'}
# {'citrus fruit'}
# {'flour'}
# {'yogurt'}
# {'bottled water'}
# {'beverages'}
# {'root vegetables'}
# {'frozen fish'}
# {'dish cleaner'}
# {'sugar'}
# {'napkins', 'yogurt'}
# {'sausage', 'tropical fruit'}
# {'tropical fruit', 'citrus fruit'}
# {'pastry', 'root vegetables'}
# {'white bread', 'soda'}
# {'other vegetables', 'hamburger meat'}
# {'whole milk', 'root vegetables'}
# {'rolls/buns', 'chocolate'}
# {'whipped/sour cream', 'curd'}
# {'pip fruit', 'whole milk'}
# {'bottled water', 'tropical fruit'}
# {'sausage', 'brown bread'}
# {'shopping bags', 'yogurt'}
# {'bottled water', 'newspapers'}
# {'whipped/sour cream', 'other vegetables'}
# {'whole milk', 'yogurt'}
# {'tropical fruit', 'root vegetables'}
# {'soda', 'citrus fruit'}
# {'margarine', 'soda'}
# {'whole milk', 'oil'}
# {'sausage', 'soda'}
# {'bottled water', 'citrus fruit'}
# {'margarine', 'bottled water'}
# {'frozen vegetables', 'yogurt'}
# {'other vegetables', 'shopping bags'}
# {'whole milk', 'beef'}
# {'whole milk', 'pork'}
# {'rolls/buns', 'yogurt'}
# {'shopping bags', 'soda'}
# {'brown bread', 'root vegetables'}
# {'rolls/buns', 'citrus fruit'}
# {'frozen vegetables', 'root vegetables'}
# {'rolls/buns', 'domestic eggs'}
# {'bottled water', 'fruit/vegetable juice'}
# {'margarine', 'rolls/buns'}
# {'sausage', 'rolls/buns'}
# {'cream cheese', 'yogurt'}
# {'pastry', 'pip fruit'}
# {'soda', 'fruit/vegetable juice'}
# {'whole milk', 'dessert'}
# {'sausage', 'yogurt'}
# {'whipped/sour cream', 'whole milk'}
# {'root vegetables', 'pork'}
# {'other vegetables', 'yogurt'}
# {'root vegetables', 'chicken'}
# {'tropical fruit', 'rolls/buns'}
# {'sausage', 'frankfurter'}
# {'whole milk', 'brown bread'}
# {'butter', 'yogurt'}
# {'whole milk', 'domestic eggs'}
# {'soda', 'frankfurter'}
# {'curd', 'yogurt'}
# {'newspapers', 'root vegetables'}
# {'sausage', 'shopping bags'}
# {'other vegetables', 'curd'}
# {'other vegetables', 'whole milk'}
# {'tropical fruit', 'curd'}
# {'other vegetables', 'beef'}
# {'rolls/buns', 'root vegetables'}
# {'whole milk', 'chocolate'}
# {'brown bread', 'yogurt'}
# {'yogurt', 'fruit/vegetable juice'}
# {'tropical fruit', 'soda'}
# {'bottled water', 'bottled beer'}
# {'root vegetables', 'citrus fruit'}
# {'root vegetables', 'domestic eggs'}
# {'margarine', 'root vegetables'}
# {'bottled water', 'rolls/buns'}
# {'newspapers', 'soda'}
# {'other vegetables', 'butter'}
# {'frozen vegetables', 'rolls/buns'}
# {'shopping bags', 'tropical fruit'}
# {'whole milk', 'chicken'}
# {'whipped/sour cream', 'root vegetables'}
# {'pip fruit', 'root vegetables'}
# {'other vegetables', 'napkins'}
# {'bottled water', 'root vegetables'}
# {'whole milk', 'ham'}
# {'other vegetables', 'sausage'}
# {'citrus fruit', 'yogurt'}
# {'hygiene articles', 'whole milk'}
# {'pip fruit', 'bottled water'}
# {'whole milk', 'long life bakery product'}
# {'pastry', 'whole milk'}
# {'soda', 'root vegetables'}
# {'pip fruit', 'soda'}
# {'sausage', 'citrus fruit'}
# {'bottled water', 'soda'}
# {'tropical fruit', 'yogurt'}
# {'soda', 'yogurt'}
# {'shopping bags', 'rolls/buns'}
# {'whole milk', 'citrus fruit'}
# {'margarine', 'whole milk'}
# {'whole milk', 'bottled beer'}
# {'beef', 'yogurt'}
# {'onions', 'whole milk'}
# {'beef', 'rolls/buns'}
# {'other vegetables', 'white bread'}
# {'rolls/buns', 'curd'}
# {'whole milk', 'rolls/buns'}
# {'rolls/buns', 'fruit/vegetable juice'}
# {'other vegetables', 'pork'}
# {'root vegetables', 'yogurt'}
# {'whipped/sour cream', 'rolls/buns'}
# {'berries', 'yogurt'}
# {'napkins', 'whole milk'}
# {'root vegetables', 'frankfurter'}
# {'citrus fruit', 'fruit/vegetable juice'}
# {'whipped/sour cream', 'citrus fruit'}
# {'other vegetables', 'long life bakery product'}
# {'other vegetables', 'tropical fruit'}
# {'pastry', 'other vegetables'}
# {'pastry', 'shopping bags'}
# {'other vegetables', 'newspapers'}
# {'other vegetables', 'waffles'}
# {'other vegetables', 'cream cheese'}
# {'yogurt', 'frankfurter'}
# {'napkins', 'tropical fruit'}
# {'other vegetables', 'salty snack'}
# {'whipped/sour cream', 'soda'}
# {'hard cheese', 'whole milk'}
# {'soda', 'brown bread'}
# {'tropical fruit', 'domestic eggs'}
# {'whipped/sour cream', 'butter'}
# {'other vegetables', 'margarine'}
# {'other vegetables', 'domestic eggs'}
# {'other vegetables', 'citrus fruit'}
# {'shopping bags', 'root vegetables'}
# {'newspapers', 'rolls/buns'}
# {'other vegetables', 'onions'}
# {'newspapers', 'yogurt'}
# {'whole milk', 'white bread'}
# {'bottled water', 'shopping bags'}
# {'sausage', 'pip fruit'}
# {'frozen vegetables', 'other vegetables'}
# {'other vegetables', 'butter milk'}
# {'other vegetables', 'bottled water'}
# {'whole milk', 'frankfurter'}
# {'butter', 'rolls/buns'}
# {'canned beer', 'rolls/buns'}
# {'pastry', 'yogurt'}
# {'sausage', 'root vegetables'}
# {'other vegetables', 'fruit/vegetable juice'}
# {'pip fruit', 'tropical fruit'}
# {'other vegetables', 'sugar'}
# {'other vegetables', 'berries'}
# {'other vegetables', 'chicken'}
# {'whole milk', 'tropical fruit'}
# {'rolls/buns', 'pork'}
# {'rolls/buns', 'brown bread'}
# {'pip fruit', 'rolls/buns'}
# {'whipped/sour cream', 'yogurt'}
# {'pip fruit', 'yogurt'}
# {'whole milk', 'newspapers'}
# {'whole milk', 'cream cheese'}
# {'bottled water', 'yogurt'}
# {'pip fruit', 'citrus fruit'}
# {'sliced cheese', 'whole milk'}
# {'sausage', 'whole milk'}
# {'pastry', 'tropical fruit'}
# {'whole milk', 'salty snack'}
# {'newspapers', 'tropical fruit'}
# {'bottled beer', 'rolls/buns'}
# {'pastry', 'soda'}
# {'whole milk', 'soda'}
# {'soda', 'pork'}
# {'whole milk', 'coffee'}
# {'domestic eggs', 'yogurt'}
# {'whole milk', 'shopping bags'}
# {'frozen vegetables', 'whole milk'}
# {'shopping bags', 'fruit/vegetable juice'}
# {'bottled water', 'whole milk'}
# {'butter milk', 'whole milk'}
# {'other vegetables', 'frankfurter'}
# {'napkins', 'rolls/buns'}
# {'butter', 'root vegetables'}
# {'other vegetables', 'bottled beer'}
# {'beef', 'root vegetables'}
# {'curd', 'root vegetables'}
# {'whole milk', 'fruit/vegetable juice'}
# {'other vegetables', 'rolls/buns'}
# {'sugar', 'whole milk'}
# {'whole milk', 'berries'}
# {'bottled beer', 'soda'}
# {'sausage', 'fruit/vegetable juice'}
# {'pastry', 'rolls/buns'}
# {'other vegetables', 'dessert'}
# {'soda', 'rolls/buns'}
# {'whole milk', 'hamburger meat'}
# {'coffee', 'rolls/buns'}
# {'other vegetables', 'root vegetables'}
# {'whipped/sour cream', 'tropical fruit'}
# {'sausage', 'bottled water'}
# {'other vegetables', 'brown bread'}
# {'tropical fruit', 'fruit/vegetable juice'}
# {'tropical fruit', 'brown bread'}
# {'soda', 'domestic eggs'}
# {'other vegetables', 'pip fruit'}
# {'pastry', 'sausage'}
# {'napkins', 'soda'}
# {'waffles', 'whole milk'}
# {'other vegetables', 'soda'}
# {'other vegetables', 'coffee'}
# {'soda', 'chocolate'}
# {'canned beer', 'soda'}
# {'whole milk', 'curd'}
# {'citrus fruit', 'domestic eggs'}
# {'other vegetables', 'chocolate'}
# {'shopping bags', 'canned beer'}
# {'root vegetables', 'fruit/vegetable juice'}
# {'margarine', 'yogurt'}
# {'rolls/buns', 'frankfurter'}
# {'whole milk', 'butter'}
# {'other vegetables', 'tropical fruit', 'root vegetables'}
# {'whole milk', 'soda', 'yogurt'}
# {'whipped/sour cream', 'whole milk', 'yogurt'}
# {'other vegetables', 'whole milk', 'pork'}
# {'other vegetables', 'sausage', 'whole milk'}
# {'other vegetables', 'root vegetables', 'citrus fruit'}
# {'other vegetables', 'whole milk', 'fruit/vegetable juice'}
# {'other vegetables', 'pip fruit', 'whole milk'}
# {'other vegetables', 'whole milk', 'pastry'}
# {'other vegetables', 'whole milk', 'yogurt'}
# {'whipped/sour cream', 'whole milk', 'other vegetables'}
# {'whole milk', 'tropical fruit', 'yogurt'}
# {'whole milk', 'curd', 'yogurt'}
# {'other vegetables', 'rolls/buns', 'root vegetables'}
# {'other vegetables', 'whole milk', 'domestic eggs'}
# {'other vegetables', 'whole milk', 'tropical fruit'}
# {'whole milk', 'root vegetables', 'yogurt'}
# {'whole milk', 'citrus fruit', 'yogurt'}
# {'other vegetables', 'whole milk', 'butter'}
# {'other vegetables', 'whole milk', 'root vegetables'}
# {'whole milk', 'tropical fruit', 'root vegetables'}
# {'whole milk', 'rolls/buns', 'yogurt'}
# {'whipped/sour cream', 'other vegetables', 'yogurt'}
# {'other vegetables', 'whole milk', 'bottled water'}
# {'whole milk', 'tropical fruit', 'rolls/buns'}
# {'other vegetables', 'tropical fruit', 'yogurt'}
# {'other vegetables', 'whole milk', 'soda'}
# {'whole milk', 'rolls/buns', 'root vegetables'}
# {'other vegetables', 'root vegetables', 'yogurt'}
# {'other vegetables', 'whole milk', 'rolls/buns'}
# {'other vegetables', 'rolls/buns', 'yogurt'}
# {'other vegetables', 'whole milk', 'citrus fruit'}
#
# Association Rules:
# {'napkins'} => {'yogurt'} (Confidence: 0.23495145631067962)
# {'sausage'} => {'tropical fruit'} (Confidence: 0.14826839826839827)
# {'tropical fruit'} => {'sausage'} (Confidence: 0.13275193798449614)
# {'tropical fruit'} => {'citrus fruit'} (Confidence: 0.18992248062015504)
# {'citrus fruit'} => {'tropical fruit'} (Confidence: 0.24078624078624078)
# {'pastry'} => {'root vegetables'} (Confidence: 0.12342857142857143)
# {'root vegetables'} => {'pastry'} (Confidence: 0.10074626865671642)
# {'white bread'} => {'soda'} (Confidence: 0.24396135265700483)
# {'hamburger meat'} => {'other vegetables'} (Confidence: 0.41590214067278286)
# {'whole milk'} => {'root vegetables'} (Confidence: 0.19140469558296858)
# {'root vegetables'} => {'whole milk'} (Confidence: 0.44869402985074625)
# {'root vegetables'} => {'other vegetables', 'rolls/buns'} (Confidence: 0.11194029850746269)
# {'domestic eggs'} => {'other vegetables', 'whole milk'} (Confidence: 0.19391025641025642)
# {'tropical fruit'} => {'other vegetables', 'whole milk'} (Confidence: 0.16279069767441862)
# {'root vegetables'} => {'whole milk', 'yogurt'} (Confidence: 0.1333955223880597)
# {'yogurt'} => {'whole milk', 'root vegetables'} (Confidence: 0.10422740524781342)
# {'citrus fruit'} => {'whole milk', 'yogurt'} (Confidence: 0.12407862407862408)
# {'butter'} => {'other vegetables', 'whole milk'} (Confidence: 0.20733944954128442)
# {'other vegetables'} => {'whole milk', 'root vegetables'} (Confidence: 0.11981082501313715)
# {'root vegetables'} => {'other vegetables', 'whole milk'} (Confidence: 0.2126865671641791)
# {'tropical fruit'} => {'whole milk', 'root vegetables'} (Confidence: 0.11434108527131782)
# {'root vegetables'} => {'whole milk', 'tropical fruit'} (Confidence: 0.11007462686567164)
# {'yogurt'} => {'whole milk', 'rolls/buns'} (Confidence: 0.11151603498542274)
# {'whipped/sour cream'} => {'other vegetables', 'yogurt'} (Confidence: 0.14184397163120568)
# {'tropical fruit'} => {'whole milk', 'rolls/buns'} (Confidence: 0.10465116279069768)
# {'tropical fruit'} => {'other vegetables', 'yogurt'} (Confidence: 0.11724806201550388)
# {'root vegetables'} => {'whole milk', 'rolls/buns'} (Confidence: 0.1166044776119403)
# {'root vegetables'} => {'other vegetables', 'yogurt'} (Confidence: 0.11847014925373134)
# {'citrus fruit'} => {'other vegetables', 'whole milk'} (Confidence: 0.15724815724815724)

# %% [markdown]
# # Fk-1 x Fk-1 method

# %%
import pandas as pd

def generate_frequent_1_itemsets(transactions, min_support):
    item_counts = {}
    num_transactions = len(transactions)

    for transaction in transactions:
        for item in transaction:
            if item in item_counts:
                item_counts[item] += 1
            else:
                item_counts[item] = 1

    frequent_1_itemsets = {frozenset([item]) for item, count in item_counts.items() if count / num_transactions >= min_support}

    return frequent_1_itemsets

#Same code as above, just changed the candidate generation logic for Fk-1 x Fk-1 method
def generate_candidates(frequent_itemsets, k):
    candidates = set()
    for itemset1 in frequent_itemsets:
        for itemset2 in frequent_itemsets:
            #Ensuring that the first k-2 elements are the same
            if list(itemset1)[:-1] == list(itemset2)[:-1]:
                new_candidate = tuple(sorted(set(itemset1) | set(itemset2)))
                if len(new_candidate) == k and new_candidate not in candidates:
                    candidates.add(new_candidate)

    return candidates

def count_support(transactions, candidates):
    item_counts = {candidate: 0 for candidate in candidates}
    for transaction in transactions:
        for candidate in candidates:
            if set(candidate).issubset(set(transaction)):
                item_counts[candidate] += 1
    return item_counts

def generate_association_rules(frequent_itemsets, transactions, min_confidence):
    association_rules = []

    for itemset in frequent_itemsets:
        if len(itemset) > 1:
            for item in itemset:
                a = frozenset([item])
                c = frozenset(itemset) - a
                confidence = count_support(transactions, {itemset})[itemset] / count_support(transactions, {a})[a]
                
                if confidence >= min_confidence:
                    association_rules.append((a, c, confidence))

    return association_rules

def apriori(transactions, min_support):
    k = 1
    frequent_itemsets = generate_frequent_1_itemsets(transactions, min_support)
    result = list(frequent_itemsets)
    total_itemsets = len(frequent_itemsets)
    total_candidates = len(set().union(*transactions))

    while frequent_itemsets:
        k += 1
        candidates = generate_candidates(frequent_itemsets, k)
        total_candidates += len(candidates)
        item_counts = count_support(transactions, candidates)
        frequent_itemsets = {itemset for itemset, count in item_counts.items() if count / len(transactions) >= min_support}
        if frequent_itemsets:
            total_itemsets += len(frequent_itemsets)
            result.extend(frequent_itemsets)

    return result, total_itemsets, total_candidates

# Test set used for self-testing
# transactions = [
#     {'Bread', 'Milk'},
#     {'Bread', 'Diaper', 'Beer', 'Eggs'},
#     {'Milk', 'Diaper', 'Beer', 'Coke'},
#     {'Bread', 'Milk', 'Diaper', 'Beer'},
#     {'Bread', 'Milk', 'Diaper', 'Coke'}
# ]

df = pd.read_csv('/kaggle/input/groceries/groceries.csv', usecols=lambda column: column != 'Item(s)')

transactions = df.apply(lambda row: set(row.dropna()), axis=1).tolist()

min_support = 0.01
result, total_itemsets, total_candidates = apriori(transactions, min_support)

print(f"\nTotal number of frequent itemsets: {total_itemsets}")
print(f"Total number of candidates generated: {total_candidates} \n")

print("Frequent itemsets:")
for itemset in result:
    itemset = set(itemset)
    print(itemset)

min_confidence = 0.1
association_rules = generate_association_rules(result, transactions, min_confidence)

print("\nAssociation Rules:")
for rule in association_rules:
    print(f"{set(rule[0])} => {set(rule[1])} (Confidence: {rule[2]})")
# Out:
# Total number of frequent itemsets: 333
# Total number of candidates generated: 4674
#
# Frequent itemsets:
# {'beef'}
# {'curd'}
# {'roll products'}
# {'specialty chocolate'}
# {'meat'}
# {'mustard'}
# {'ham'}
# {'shopping bags'}
# {'pickled vegetables'}
# {'seasonal products'}
# {'frankfurter'}
# {'cake bar'}
# {'baking powder'}
# {'rolls/buns'}
# {'misc. beverages'}
# {'packaged fruit/vegetables'}
# {'whipped/sour cream'}
# {'pip fruit'}
# {'white bread'}
# {'frozen dessert'}
# {'grapes'}
# {'coffee'}
# {'soda'}
# {'flower (seeds)'}
# {'processed cheese'}
# {'butter'}
# {'hygiene articles'}
# {'pasta'}
# {'salty snack'}
# {'butter milk'}
# {'frozen vegetables'}
# {'red/blush wine'}
# {'chewing gum'}
# {'detergent'}
# {'cat food'}
# {'white wine'}
# {'long life bakery product'}
# {'pastry'}
# {'other vegetables'}
# {'UHT-milk'}
# {'cling film/bags'}
# {'waffles'}
# {'liquor'}
# {'sliced cheese'}
# {'napkins'}
# {'sausage'}
# {'domestic eggs'}
# {'margarine'}
# {'ice cream'}
# {'bottled beer'}
# {'frozen meals'}
# {'hard cheese'}
# {'potted plants'}
# {'dessert'}
# {'canned vegetables'}
# {'brown bread'}
# {'whole milk'}
# {'dishes'}
# {'condensed milk'}
# {'tropical fruit'}
# {'spread cheese'}
# {'chocolate'}
# {'cream cheese'}
# {'herbs'}
# {'specialty bar'}
# {'onions'}
# {'berries'}
# {'canned fish'}
# {'soft cheese'}
# {'fruit/vegetable juice'}
# {'pork'}
# {'chicken'}
# {'semi-finished bread'}
# {'canned beer'}
# {'salt'}
# {'oil'}
# {'newspapers'}
# {'candy'}
# {'hamburger meat'}
# {'citrus fruit'}
# {'flour'}
# {'yogurt'}
# {'bottled water'}
# {'beverages'}
# {'root vegetables'}
# {'frozen fish'}
# {'dish cleaner'}
# {'sugar'}
# {'canned beer', 'rolls/buns'}
# {'whole milk', 'chocolate'}
# {'other vegetables', 'newspapers'}
# {'soda', 'domestic eggs'}
# {'sausage', 'whole milk'}
# {'other vegetables', 'pastry'}
# {'other vegetables', 'chicken'}
# {'rolls/buns', 'yogurt'}
# {'tropical fruit', 'brown bread'}
# {'other vegetables', 'dessert'}
# {'other vegetables', 'salty snack'}
# {'domestic eggs', 'yogurt'}
# {'rolls/buns', 'frankfurter'}
# {'hygiene articles', 'whole milk'}
# {'whipped/sour cream', 'rolls/buns'}
# {'other vegetables', 'berries'}
# {'butter', 'rolls/buns'}
# {'whole milk', 'rolls/buns'}
# {'newspapers', 'soda'}
# {'other vegetables', 'butter'}
# {'other vegetables', 'citrus fruit'}
# {'whole milk', 'soda'}
# {'margarine', 'soda'}
# {'pip fruit', 'root vegetables'}
# {'newspapers', 'yogurt'}
# {'other vegetables', 'beef'}
# {'margarine', 'yogurt'}
# {'other vegetables', 'sugar'}
# {'root vegetables', 'pork'}
# {'pastry', 'soda'}
# {'soda', 'citrus fruit'}
# {'other vegetables', 'root vegetables'}
# {'bottled water', 'bottled beer'}
# {'bottled water', 'newspapers'}
# {'other vegetables', 'bottled beer'}
# {'whole milk', 'long life bakery product'}
# {'onions', 'whole milk'}
# {'pastry', 'yogurt'}
# {'sausage', 'bottled water'}
# {'citrus fruit', 'yogurt'}
# {'sausage', 'fruit/vegetable juice'}
# {'tropical fruit', 'soda'}
# {'whipped/sour cream', 'citrus fruit'}
# {'beef', 'yogurt'}
# {'pip fruit', 'rolls/buns'}
# {'whole milk', 'oil'}
# {'napkins', 'soda'}
# {'frozen vegetables', 'other vegetables'}
# {'rolls/buns', 'pork'}
# {'other vegetables', 'rolls/buns'}
# {'whipped/sour cream', 'tropical fruit'}
# {'pastry', 'sausage'}
# {'sausage', 'citrus fruit'}
# {'napkins', 'yogurt'}
# {'bottled water', 'citrus fruit'}
# {'butter milk', 'whole milk'}
# {'sausage', 'shopping bags'}
# {'other vegetables', 'brown bread'}
# {'other vegetables', 'pip fruit'}
# {'other vegetables', 'tropical fruit'}
# {'napkins', 'whole milk'}
# {'curd', 'yogurt'}
# {'cream cheese', 'yogurt'}
# {'bottled water', 'soda'}
# {'soda', 'fruit/vegetable juice'}
# {'frozen vegetables', 'yogurt'}
# {'whipped/sour cream', 'curd'}
# {'other vegetables', 'frankfurter'}
# {'shopping bags', 'rolls/buns'}
# {'soda', 'brown bread'}
# {'pip fruit', 'tropical fruit'}
# {'canned beer', 'soda'}
# {'soda', 'root vegetables'}
# {'bottled water', 'yogurt'}
# {'rolls/buns', 'chocolate'}
# {'whole milk', 'domestic eggs'}
# {'whole milk', 'cream cheese'}
# {'yogurt', 'fruit/vegetable juice'}
# {'other vegetables', 'chocolate'}
# {'brown bread', 'yogurt'}
# {'other vegetables', 'hamburger meat'}
# {'root vegetables', 'yogurt'}
# {'soda', 'frankfurter'}
# {'bottled water', 'whole milk'}
# {'whole milk', 'fruit/vegetable juice'}
# {'sausage', 'tropical fruit'}
# {'whipped/sour cream', 'root vegetables'}
# {'sausage', 'pip fruit'}
# {'whole milk', 'newspapers'}
# {'whipped/sour cream', 'yogurt'}
# {'yogurt', 'frankfurter'}
# {'berries', 'yogurt'}
# {'butter', 'yogurt'}
# {'margarine', 'whole milk'}
# {'shopping bags', 'soda'}
# {'tropical fruit', 'rolls/buns'}
# {'sausage', 'brown bread'}
# {'whipped/sour cream', 'butter'}
# {'pastry', 'shopping bags'}
# {'sausage', 'root vegetables'}
# {'tropical fruit', 'domestic eggs'}
# {'shopping bags', 'yogurt'}
# {'pastry', 'whole milk'}
# {'whole milk', 'citrus fruit'}
# {'soda', 'bottled beer'}
# {'tropical fruit', 'yogurt'}
# {'whole milk', 'beef'}
# {'other vegetables', 'long life bakery product'}
# {'sausage', 'frankfurter'}
# {'coffee', 'rolls/buns'}
# {'other vegetables', 'coffee'}
# {'bottled water', 'fruit/vegetable juice'}
# {'whole milk', 'tropical fruit'}
# {'other vegetables', 'pork'}
# {'other vegetables', 'waffles'}
# {'whole milk', 'yogurt'}
# {'whole milk', 'bottled beer'}
# {'pip fruit', 'soda'}
# {'rolls/buns', 'root vegetables'}
# {'root vegetables', 'domestic eggs'}
# {'soda', 'pork'}
# {'pip fruit', 'yogurt'}
# {'other vegetables', 'soda'}
# {'whole milk', 'curd'}
# {'citrus fruit', 'fruit/vegetable juice'}
# {'other vegetables', 'yogurt'}
# {'pip fruit', 'whole milk'}
# {'frozen vegetables', 'whole milk'}
# {'newspapers', 'root vegetables'}
# {'bottled water', 'shopping bags'}
# {'other vegetables', 'whipped/sour cream'}
# {'shopping bags', 'fruit/vegetable juice'}
# {'whole milk', 'pork'}
# {'margarine', 'root vegetables'}
# {'canned beer', 'shopping bags'}
# {'shopping bags', 'root vegetables'}
# {'whole milk', 'brown bread'}
# {'napkins', 'tropical fruit'}
# {'whole milk', 'root vegetables'}
# {'soda', 'chocolate'}
# {'whole milk', 'chicken'}
# {'rolls/buns', 'domestic eggs'}
# {'pastry', 'root vegetables'}
# {'root vegetables', 'citrus fruit'}
# {'other vegetables', 'domestic eggs'}
# {'whole milk', 'dessert'}
# {'other vegetables', 'sausage'}
# {'whipped/sour cream', 'whole milk'}
# {'tropical fruit', 'curd'}
# {'whole milk', 'frankfurter'}
# {'whole milk', 'berries'}
# {'beef', 'root vegetables'}
# {'whole milk', 'butter'}
# {'newspapers', 'rolls/buns'}
# {'pip fruit', 'bottled water'}
# {'margarine', 'bottled water'}
# {'hard cheese', 'whole milk'}
# {'other vegetables', 'white bread'}
# {'whole milk', 'hamburger meat'}
# {'whole milk', 'shopping bags'}
# {'margarine', 'rolls/buns'}
# {'citrus fruit', 'domestic eggs'}
# {'tropical fruit', 'fruit/vegetable juice'}
# {'onions', 'other vegetables'}
# {'other vegetables', 'margarine'}
# {'bottled water', 'tropical fruit'}
# {'newspapers', 'tropical fruit'}
# {'tropical fruit', 'root vegetables'}
# {'soda', 'yogurt'}
# {'pastry', 'rolls/buns'}
# {'rolls/buns', 'citrus fruit'}
# {'whipped/sour cream', 'soda'}
# {'curd', 'root vegetables'}
# {'pastry', 'pip fruit'}
# {'pip fruit', 'citrus fruit'}
# {'whole milk', 'ham'}
# {'beef', 'rolls/buns'}
# {'frozen vegetables', 'root vegetables'}
# {'tropical fruit', 'citrus fruit'}
# {'pastry', 'tropical fruit'}
# {'sausage', 'rolls/buns'}
# {'whole milk', 'white bread'}
# {'bottled water', 'root vegetables'}
# {'shopping bags', 'tropical fruit'}
# {'other vegetables', 'butter milk'}
# {'root vegetables', 'fruit/vegetable juice'}
# {'rolls/buns', 'bottled beer'}
# {'brown bread', 'root vegetables'}
# {'napkins', 'rolls/buns'}
# {'whole milk', 'coffee'}
# {'other vegetables', 'shopping bags'}
# {'other vegetables', 'napkins'}
# {'root vegetables', 'chicken'}
# {'other vegetables', 'whole milk'}
# {'waffles', 'whole milk'}
# {'white bread', 'soda'}
# {'rolls/buns', 'curd'}
# {'sliced cheese', 'whole milk'}
# {'root vegetables', 'frankfurter'}
# {'other vegetables', 'curd'}
# {'butter', 'root vegetables'}
# {'sausage', 'soda'}
# {'other vegetables', 'cream cheese'}
# {'frozen vegetables', 'rolls/buns'}
# {'sugar', 'whole milk'}
# {'bottled water', 'rolls/buns'}
# {'whole milk', 'salty snack'}
# {'sausage', 'yogurt'}
# {'rolls/buns', 'fruit/vegetable juice'}
# {'other vegetables', 'bottled water'}
# {'other vegetables', 'fruit/vegetable juice'}
# {'rolls/buns', 'brown bread'}
# {'soda', 'rolls/buns'}
# {'whole milk', 'citrus fruit', 'yogurt'}
# {'other vegetables', 'whole milk', 'tropical fruit'}
# {'other vegetables', 'whole milk', 'pastry'}
# {'other vegetables', 'sausage', 'whole milk'}
# {'whole milk', 'soda', 'yogurt'}
# {'other vegetables', 'rolls/buns', 'yogurt'}
# {'other vegetables', 'whole milk', 'yogurt'}
# {'whole milk', 'rolls/buns', 'yogurt'}
# {'whole milk', 'tropical fruit', 'rolls/buns'}
# {'other vegetables', 'whole milk', 'fruit/vegetable juice'}
# {'other vegetables', 'rolls/buns', 'root vegetables'}
# {'other vegetables', 'whole milk', 'butter'}
# {'whole milk', 'root vegetables', 'yogurt'}
# {'other vegetables', 'tropical fruit', 'root vegetables'}
# {'other vegetables', 'bottled water', 'whole milk'}
# {'other vegetables', 'whole milk', 'rolls/buns'}
# {'other vegetables', 'whole milk', 'soda'}
# {'other vegetables', 'root vegetables', 'citrus fruit'}
# {'whole milk', 'tropical fruit', 'root vegetables'}
# {'whipped/sour cream', 'whole milk', 'yogurt'}
# {'other vegetables', 'whole milk', 'citrus fruit'}
# {'other vegetables', 'pip fruit', 'whole milk'}
# {'other vegetables', 'yogurt', 'whipped/sour cream'}
# {'other vegetables', 'whole milk', 'pork'}
# {'other vegetables', 'root vegetables', 'yogurt'}
# {'other vegetables', 'whole milk', 'domestic eggs'}
# {'whole milk', 'rolls/buns', 'root vegetables'}
# {'other vegetables', 'whole milk', 'whipped/sour cream'}
# {'other vegetables', 'whole milk', 'root vegetables'}
# {'whole milk', 'curd', 'yogurt'}
# {'other vegetables', 'tropical fruit', 'yogurt'}
# {'whole milk', 'tropical fruit', 'yogurt'}
#
# Association Rules:
# {'canned beer'} => {'rolls/buns'} (Confidence: 0.14528795811518325)
# {'chocolate'} => {'whole milk'} (Confidence: 0.3360655737704918)
# {'newspapers'} => {'other vegetables'} (Confidence: 0.24203821656050956)
# {'domestic eggs'} => {'soda'} (Confidence: 0.1955128205128205)
# {'sausage'} => {'whole milk'} (Confidence: 0.3181818181818182)
# {'whole milk'} => {'sausage'} (Confidence: 0.116991643454039)
# {'other vegetables'} => {'pastry'} (Confidence: 0.11665790856542302)
# {'pastry'} => {'other vegetables'} (Confidence: 0.2537142857142857)
# {'chicken'} => {'other vegetables'} (Confidence: 0.41706161137440756)
# {'rolls/buns'} => {'yogurt'} (Confidence: 0.18684355997788835)
# {'yogurt'} => {'rolls/buns'} (Confidence: 0.24635568513119532)
# {'brown bread'} => {'tropical fruit'} (Confidence: 0.164576802507837)
# {'tropical fruit'} => {'brown bread'} (Confidence: 0.10174418604651163)
# {'dessert'} => {'other vegetables'} (Confidence: 0.31232876712328766)
# {'salty snack'} => {'other vegetables'} (Confidence: 0.2849462365591398)
# {'domestic eggs'} => {'yogurt'} (Confidence: 0.22596153846153846)
# {'yogurt'} => {'domestic eggs'} (Confidence: 0.10276967930029154)
# {'frankfurter'} => {'rolls/buns'} (Confidence: 0.3258620689655172)
# {'rolls/buns'} => {'frankfurter'} (Confidence: 0.1044776119402985)
# {'hygiene articles'} => {'whole milk'} (Confidence: 0.3888888888888889)
# {'whipped/sour cream'} => {'rolls/buns'} (Confidence: 0.20425531914893616)
# {'berries'} => {'other vegetables'} (Confidence: 0.308868501529052)
# {'butter'} => {'rolls/buns'} (Confidence: 0.24220183486238533)
# {'rolls/buns'} => {'whole milk'} (Confidence: 0.30790491984521834)
# {'whole milk'} => {'rolls/buns'} (Confidence: 0.2216474333465977)
# {'newspapers'} => {'soda'} (Confidence: 0.18343949044585986)
# {'butter'} => {'other vegetables'} (Confidence: 0.3614678899082569)
# {'other vegetables'} => {'butter'} (Confidence: 0.10352075669994745)
# {'citrus fruit'} => {'other vegetables'} (Confidence: 0.3488943488943489)
# {'other vegetables'} => {'citrus fruit'} (Confidence: 0.14923804519180242)
# {'soda'} => {'whole milk'} (Confidence: 0.22973760932944606)
# {'whole milk'} => {'soda'} (Confidence: 0.15678471945881417)
# {'margarine'} => {'soda'} (Confidence: 0.1736111111111111)
# {'pip fruit'} => {'root vegetables'} (Confidence: 0.2056451612903226)
# {'rolls/buns'} => {'soda'} (Confidence: 0.2084024322830293)
# {'soda'} => {'rolls/buns'} (Confidence: 0.21982507288629738)
# {'citrus fruit'} => {'whole milk', 'yogurt'} (Confidence: 0.12407862407862408)
# {'tropical fruit'} => {'other vegetables', 'whole milk'} (Confidence: 0.16279069767441862)
# {'pastry'} => {'other vegetables', 'whole milk'} (Confidence: 0.11885714285714286)
# {'sausage'} => {'other vegetables', 'whole milk'} (Confidence: 0.10822510822510822)
# {'other vegetables'} => {'whole milk', 'yogurt'} (Confidence: 0.11508145034156594)
# {'yogurt'} => {'other vegetables', 'whole milk'} (Confidence: 0.15962099125364432)
# {'yogurt'} => {'whole milk', 'rolls/buns'} (Confidence: 0.11151603498542274)
# {'tropical fruit'} => {'whole milk', 'rolls/buns'} (Confidence: 0.10465116279069768)
# {'fruit/vegetable juice'} => {'other vegetables', 'whole milk'} (Confidence: 0.14486638537271448)
# {'root vegetables'} => {'other vegetables', 'rolls/buns'} (Confidence: 0.11194029850746269)
# {'butter'} => {'other vegetables', 'whole milk'} (Confidence: 0.20733944954128442)
# {'root vegetables'} => {'whole milk', 'yogurt'} (Confidence: 0.1333955223880597)
# {'yogurt'} => {'whole milk', 'root vegetables'} (Confidence: 0.10422740524781342)
# {'root vegetables'} => {'other vegetables', 'tropical fruit'} (Confidence: 0.11287313432835822)
# {'tropical fruit'} => {'other vegetables', 'root vegetables'} (Confidence: 0.11724806201550388)
# {'citrus fruit'} => {'other vegetables', 'root vegetables'} (Confidence: 0.12530712530712532)
# {'root vegetables'} => {'whole milk', 'tropical fruit'} (Confidence: 0.11007462686567164)
# {'tropical fruit'} => {'whole milk', 'root vegetables'} (Confidence: 0.11434108527131782)
# {'whipped/sour cream'} => {'whole milk', 'yogurt'} (Confidence: 0.15177304964539007)
# {'citrus fruit'} => {'other vegetables', 'whole milk'} (Confidence: 0.15724815724815724)
# {'pip fruit'} => {'other vegetables', 'whole milk'} (Confidence: 0.17876344086021506)
# {'whipped/sour cream'} => {'other vegetables', 'yogurt'} (Confidence: 0.14184397163120568)
# {'pork'} => {'other vegetables', 'whole milk'} (Confidence: 0.1763668430335097)
# {'root vegetables'} => {'other vegetables', 'yogurt'} (Confidence: 0.11847014925373134)
# {'domestic eggs'} => {'other vegetables', 'whole milk'} (Confidence: 0.19391025641025642)
# {'root vegetables'} => {'whole milk', 'rolls/buns'} (Confidence: 0.1166044776119403)
# {'whipped/sour cream'} => {'other vegetables', 'whole milk'} (Confidence: 0.20425531914893616)
# {'other vegetables'} => {'whole milk', 'root vegetables'} (Confidence: 0.11981082501313715)
# {'root vegetables'} => {'other vegetables', 'whole milk'} (Confidence: 0.2126865671641791)
# {'curd'} => {'whole milk', 'yogurt'} (Confidence: 0.18893129770992367)
# {'tropical fruit'} => {'other vegetables', 'yogurt'} (Confidence: 0.11724806201550388)
# {'tropical fruit'} => {'whole milk', 'yogurt'} (Confidence: 0.14437984496124032)
# {'yogurt'} => {'whole milk', 'tropical fruit'} (Confidence: 0.10860058309037901)
